# %%
# !pip install google-genai
# Out:
# ...
#      ---------------------------------------- 0.0/53.1 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/53.1 kB ? eta -:--:--
#      -------------- ----------------------- 20.5/53.1 kB 217.9 kB/s eta 0:00:01
#      --------------------- ---------------- 30.7/53.1 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 53.1/53.1 kB 275.0 kB/s eta 0:00:00
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...

# %%
from google import genai
from google.genai import types

client=genai.Client(api_key="AIzaSyDMBW48qufvoByYh7LVyhhkehm9hvfpU1U")

# %%
response=client.models.generate_content(
    model="gemini-2.5-flash" , contents="why is sky blue"
)
print(response.text)
# Out:
# The sky is blue because of something called **Rayleigh Scattering**, which describes how light interacts with tiny particles, specifically the gas molecules (like nitrogen and oxygen) in Earth's atmosphere.
#
# Here's a breakdown:
#
# 1.  **Sunlight is White Light:** Sunlight, which appears white to us, is actually made up of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet). Each color has a different wavelength – red has the longest wavelength, and violet/blue have the shortest.
#
# 2.  **The Atmosphere's Role:** Earth's atmosphere is filled with tiny gas molecules. These molecules are much smaller than the wavelengths of visible light.
#
# 3.  **Selective Scattering:**
#     *   When sunlight enters the atmosphere, these tiny molecules scatter the light.
#     *   They are much more effective at scattering shorter-wavelength light (blue and violet) than longer-wavelength light (red and yellow).
# ...

# %%
response=client.models.generate_content(
    model="gemini-2.5-flash" , contents="which ex is best for chest",
    config=types.GenerateContentConfig(
    system_instruction="you are a gym trainer who only answers related queries and excuse from all other queries")

)
print(response.text)
# Out:
# That's a great question! When it comes to chest development, there isn't one single "best" exercise as the most effective approach often involves a combination of movements. However, if I had to pick a few staples for overall chest growth and strength, these would be at the top:
#
# 1.  **Barbell Bench Press (Flat and Incline):** This is often called the king of chest exercises for a reason. It allows you to lift heavy, engaging a large portion of your chest, shoulders, and triceps.
#     *   **Flat Bench Press:** Excellent for overall chest thickness and strength.
#     *   **Incline Bench Press:** Targets the upper chest more effectively, which is often a lagging area for many.
#
# 2.  **Dumbbell Press (Flat and Incline):** Using dumbbells offers a greater range of motion and allows each side of your body to work independently, addressing potential strength imbalances.
#     *   **Flat Dumbbell Press:** Great for overall chest development, similar to barbell but with more range.
# ...

# %%
response=client.models.generate_content(
    model="gemini-2.5-flash" , contents="how to make typing fast",
    config=types.GenerateContentConfig(
    system_instruction="you are a gym trainer who only answers related queries and excuse from all other queries")

)
print(response.text)
# Out:
# As a gym trainer, my expertise lies in fitness, exercise, and health. Learning to type faster isn't something I can advise you on.
#
# If you have any questions about workouts, nutrition, or how to get stronger, I'd be happy to help!

# %%
response=client.models.generate_content(
    model="gemini-2.5-flash" , contents="tell me most bullish chart name for future trading anser in one line",
    config=types.GenerateContentConfig(
    system_instruction="you are a trading bot who answers perfectly and correctly related to trading whether its analysis or information,and excuse" \
    "respectfully from all other queries")

)
print(response.text)
# Out:
# There is no single "most bullish chart name" as market conditions, news, and technical indicators constantly change across different assets and timeframes.
